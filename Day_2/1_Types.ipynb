# %%
print(type("xyz"))
print(type(1))
print(type(1.34))
print(type(("hey","god")))
print(type(False))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'tuple'>
# <class 'bool'>

# %%
print("My age: " + str(12))
# Out:
# My age: 12

# %%
x = 345.654332
print(round(x,2))
print(round(x,1))
print(round(x,4))

x = 5
x += 5
print(x)
# Out:
# 345.65
# 345.7
# 345.6543
# 10
